# %%
import os
import skimage
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
from torchvision import transforms
from collections import OrderedDict
import torch
import clip
from torchvision.datasets import CIFAR100
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
# Load the model
device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load('ViT-B/32', device)

# Download the dataset
cifar100 = CIFAR100(root=os.path.expanduser("~/.cache"), download=True, train=False)
# Out:
# Files already downloaded and verified

# %%
# Prepare the lists to store accuracy and loss values
accuracies = []
losses = []
testing_num = 0
testing_right = 0

with torch.no_grad():
    model.eval()

    for index in range(len(cifar100)):
        if testing_num >= 100:  # Stop after 100 steps
            break

        image, label = cifar100[index]
        image_input = preprocess(image).unsqueeze(0).to(device)
        text_input = torch.cat([clip.tokenize(f"a photo of a {c}") for c in cifar100.classes]).to(device)

        with torch.no_grad():
            image_features = model.encode_image(image_input)
            text_features = model.encode_text(text_input)

        image_features /= image_features.norm(dim=-1, keepdim=True)
        text_features /= text_features.norm(dim=-1, keepdim=True)
        similarity = (100.0 * image_features @ text_features.T).softmax(dim=-1)
        value, predict = similarity[0].topk(1)
        loss = value.item() * 0.01
        testing_loss.append(loss)
        
        if predict == label:
            testing_right += 1
        
        current_accuracy = testing_right / (testing_num + 1)
        accuracies.append(current_accuracy)  # Append current accuracy to the list
        losses.append(loss)  # Append current loss to the list
        print(f"Accuracy at step {testing_num + 1}: {current_accuracy * 100:.2f}%")
            
        testing_num += 1

# Plotting accuracy and loss curves for the first 100 steps
plt.figure(figsize=(10, 5))

plt.plot(range(1, len(accuracies) + 1), accuracies, label='Accuracy', color='blue')
plt.plot(range(1, len(losses) + 1), losses, label='Loss', color='red')
plt.xlabel('Steps')
plt.ylabel('Accuracy / Loss')
plt.title('Accuracy and Loss Curves for First 100 Steps')
plt.legend()

plt.show()
# Out:
# Accuracy at step 1: 0.00%
# Accuracy at step 2: 0.00%
# Accuracy at step 3: 0.00%
# Accuracy at step 4: 25.00%
# Accuracy at step 5: 40.00%
# Accuracy at step 6: 50.00%
# Accuracy at step 7: 57.14%
# Accuracy at step 8: 50.00%
# Accuracy at step 9: 44.44%
# Accuracy at step 10: 50.00%
# Accuracy at step 11: 45.45%
# Accuracy at step 12: 50.00%
# Accuracy at step 13: 53.85%
# Accuracy at step 14: 57.14%
# Accuracy at step 15: 60.00%
# Accuracy at step 16: 62.50%
# Accuracy at step 17: 64.71%
# Accuracy at step 18: 61.11%
# Accuracy at step 19: 63.16%
# Accuracy at step 20: 65.00%
# Accuracy at step 21: 66.67%
# Accuracy at step 22: 68.18%
# Accuracy at step 23: 69.57%
# Accuracy at step 24: 70.83%
# Accuracy at step 25: 72.00%
# Accuracy at step 26: 73.08%
# Accuracy at step 27: 74.07%
# Accuracy at step 28: 75.00%
# Accuracy at step 29: 75.86%
# Accuracy at step 30: 73.33%
# Accuracy at step 31: 74.19%
# Accuracy at step 32: 75.00%
# Accuracy at step 33: 75.76%
# Accuracy at step 34: 73.53%
# Accuracy at step 35: 74.29%
# Accuracy at step 36: 72.22%
# Accuracy at step 37: 72.97%
# Accuracy at step 38: 73.68%
# Accuracy at step 39: 74.36%
# Accuracy at step 40: 75.00%
# Accuracy at step 41: 75.61%
# Accuracy at step 42: 73.81%
# Accuracy at step 43: 74.42%
# Accuracy at step 44: 75.00%
# Accuracy at step 45: 75.56%
# Accuracy at step 46: 73.91%
# Accuracy at step 47: 74.47%
# Accuracy at step 48: 75.00%
# Accuracy at step 49: 73.47%
# Accuracy at step 50: 74.00%
# Accuracy at step 51: 72.55%
# Accuracy at step 52: 73.08%
# Accuracy at step 53: 73.58%
# Accuracy at step 54: 74.07%
# Accuracy at step 55: 74.55%
# Accuracy at step 56: 75.00%
# Accuracy at step 57: 75.44%
# Accuracy at step 58: 75.86%
# Accuracy at step 59: 76.27%
# Accuracy at step 60: 76.67%
# Accuracy at step 61: 77.05%
# Accuracy at step 62: 75.81%
# Accuracy at step 63: 76.19%
# Accuracy at step 64: 75.00%
# Accuracy at step 65: 73.85%
# Accuracy at step 66: 74.24%
# Accuracy at step 67: 74.63%
# Accuracy at step 68: 75.00%
# Accuracy at step 69: 73.91%
# Accuracy at step 70: 74.29%
# Accuracy at step 71: 73.24%
# Accuracy at step 72: 73.61%
# Accuracy at step 73: 72.60%
# Accuracy at step 74: 71.62%
# Accuracy at step 75: 70.67%
# Accuracy at step 76: 71.05%
# Accuracy at step 77: 71.43%
# Accuracy at step 78: 70.51%
# Accuracy at step 79: 70.89%
# Accuracy at step 80: 71.25%
# Accuracy at step 81: 71.60%
# Accuracy at step 82: 71.95%
# Accuracy at step 83: 72.29%
# Accuracy at step 84: 72.62%
# Accuracy at step 85: 72.94%
# Accuracy at step 86: 72.09%
# Accuracy at step 87: 71.26%
# Accuracy at step 88: 70.45%
# Accuracy at step 89: 70.79%
# Accuracy at step 90: 70.00%
# Accuracy at step 91: 70.33%
# Accuracy at step 92: 69.57%
# Accuracy at step 93: 68.82%
# Accuracy at step 94: 69.15%
# Accuracy at step 95: 69.47%
# Accuracy at step 96: 69.79%
# Accuracy at step 97: 69.07%
# Accuracy at step 98: 68.37%
# Accuracy at step 99: 68.69%
# Accuracy at step 100: 69.00%

# %%
# Load the model, preprocess, and obtain predictions and labels

predictions = []  # Store the predicted labels
true_labels = []  # Store the true labels

with torch.no_grad():
    model.eval()

    for index in range(len(cifar100)):
        if len(predictions) >= 100:  # Stop after 100 steps
            break

        image, label = cifar100[index]
        image_input = preprocess(image).unsqueeze(0).to(device)
        text_input = torch.cat([clip.tokenize(f"a photo of a {c}") for c in cifar100.classes]).to(device)

        with torch.no_grad():
            image_features = model.encode_image(image_input)
            text_features = model.encode_text(text_input)

        image_features /= image_features.norm(dim=-1, keepdim=True)
        text_features /= text_features.norm(dim=-1, keepdim=True)
        similarity = (100.0 * image_features @ text_features.T).softmax(dim=-1)
        value, predict = similarity[0].topk(1)
        
        predictions.append(predict.item())  # Append the predicted label
        true_labels.append(label)  # Append the true label
        
        print(f"Prediction at step {len(predictions)}: {predict.item()}, True label: {label}")

# Generate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predictions)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Prediction at step 1: 58, True label: 49
# Prediction at step 2: 41, True label: 33
# Prediction at step 3: 59, True label: 72
# Prediction at step 4: 51, True label: 51
# Prediction at step 5: 71, True label: 71
# Prediction at step 6: 92, True label: 92
# Prediction at step 7: 15, True label: 15
# Prediction at step 8: 47, True label: 14
# Prediction at step 9: 60, True label: 23
# Prediction at step 10: 0, True label: 0
# Prediction at step 11: 59, True label: 71
# Prediction at step 12: 75, True label: 75
# Prediction at step 13: 81, True label: 81
# Prediction at step 14: 69, True label: 69
# Prediction at step 15: 40, True label: 40
# Prediction at step 16: 43, True label: 43
# Prediction at step 17: 92, True label: 92
# Prediction at step 18: 15, True label: 97
# Prediction at step 19: 70, True label: 70
# Prediction at step 20: 53, True label: 53
# Prediction at step 21: 70, True label: 70
# Prediction at step 22: 49, True label: 49
# Prediction at step 23: 75, True label: 75
# Prediction at step 24: 29, True label: 29
# Prediction at step 25: 21, True label: 21
# Prediction at step 26: 16, True label: 16
# Prediction at step 27: 39, True label: 39
# Prediction at step 28: 8, True label: 8
# Prediction at step 29: 8, True label: 8
# Prediction at step 30: 62, True label: 70
# Prediction at step 31: 20, True label: 20
# Prediction at step 32: 61, True label: 61
# Prediction at step 33: 41, True label: 41
# Prediction at step 34: 32, True label: 93
# Prediction at step 35: 56, True label: 56
# Prediction at step 36: 30, True label: 73
# Prediction at step 37: 58, True label: 58
# Prediction at step 38: 11, True label: 11
# Prediction at step 39: 25, True label: 25
# Prediction at step 40: 37, True label: 37
# Prediction at step 41: 63, True label: 63
# Prediction at step 42: 1, True label: 24
# Prediction at step 43: 49, True label: 49
# Prediction at step 44: 73, True label: 73
# Prediction at step 45: 56, True label: 56
# Prediction at step 46: 41, True label: 22
# Prediction at step 47: 41, True label: 41
# Prediction at step 48: 58, True label: 58
# Prediction at step 49: 56, True label: 75
# Prediction at step 50: 17, True label: 17
# Prediction at step 51: 21, True label: 4
# Prediction at step 52: 6, True label: 6
# Prediction at step 53: 9, True label: 9
# Prediction at step 54: 57, True label: 57
# Prediction at step 55: 2, True label: 2
# Prediction at step 56: 32, True label: 32
# Prediction at step 57: 71, True label: 71
# Prediction at step 58: 52, True label: 52
# Prediction at step 59: 42, True label: 42
# Prediction at step 60: 69, True label: 69
# Prediction at step 61: 77, True label: 77
# Prediction at step 62: 32, True label: 27
# Prediction at step 63: 15, True label: 15
# Prediction at step 64: 75, True label: 65
# Prediction at step 65: 26, True label: 7
# Prediction at step 66: 35, True label: 35
# Prediction at step 67: 43, True label: 43
# Prediction at step 68: 82, True label: 82
# Prediction at step 69: 66, True label: 63
# Prediction at step 70: 92, True label: 92
# Prediction at step 71: 20, True label: 66
# Prediction at step 72: 90, True label: 90
# Prediction at step 73: 1, True label: 67
# Prediction at step 74: 74, True label: 91
# Prediction at step 75: 57, True label: 32
# Prediction at step 76: 32, True label: 32
# Prediction at step 77: 82, True label: 82
# Prediction at step 78: 28, True label: 10
# Prediction at step 79: 77, True label: 77
# Prediction at step 80: 22, True label: 22
# Prediction at step 81: 71, True label: 71
# Prediction at step 82: 78, True label: 78
# Prediction at step 83: 54, True label: 54
# Prediction at step 84: 6, True label: 6
# Prediction at step 85: 29, True label: 29
# Prediction at step 86: 41, True label: 89
# Prediction at step 87: 99, True label: 78
# Prediction at step 88: 68, True label: 33
# Prediction at step 89: 11, True label: 11
# Prediction at step 90: 69, True label: 67
# Prediction at step 91: 22, True label: 22
# Prediction at step 92: 96, True label: 18
# Prediction at step 93: 32, True label: 27
# Prediction at step 94: 21, True label: 21
# Prediction at step 95: 13, True label: 13
# Prediction at step 96: 21, True label: 21
# Prediction at step 97: 74, True label: 50
# Prediction at step 98: 44, True label: 75
# Prediction at step 99: 37, True label: 37
# Prediction at step 100: 35, True label: 35
